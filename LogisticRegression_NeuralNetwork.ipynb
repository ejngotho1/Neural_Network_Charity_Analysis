# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# read data into a df
diabetes_df = pd.read_csv("diabetes.csv")
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ##### -- this dataset is sufficeint for both logical regression and Neural network
# ##### -- data needs no preprocessing or scaling this data for Logistic regression
# ##### -- Neural Network needs the data to be standardized/normalized -- so we will scale the data

# %%
# first off we need to remove outcomes from the data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# we then need split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %% [markdown]
# --------------------------------------------------------------
# ####  here we will standardize/normalize by scaling for nn
# --------------------------------------------------------------

# %%
# we standardize the numerical variable, to preprocess the data for nueral network

# first create a scaler instance
scaler = StandardScaler()

# next fit the StandardScaler with input training data (X_train)
X_scaler = scaler.fit(X_train)

# scale/transform the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ================================================================
# #### we are ready to train both the logistical and neural models
# ----------------------------------------------------------------
# ### we train Logistic model first
# ================================================================

# %% [markdown]
# #### logistic Regression models are built using Scikits --LogisticRegression class IN the Linear_model
# #### Parameters used in this model
#   #### - Solver set to 'lbfgs' ---an algorithn for learning and optimizing (there are many optimizers, choice is yours)
#   #### - Iteration parameter---max_iter = set to 200 iterations - will give us opportunity to converge on effective weights

# %%
# define / building logistic regression model
log_classifier = LogisticRegression(solver='lbfgs', max_iter=200)

# %%
# train the model--fit the training data into the logistc regression MODEL
log_classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
# now we can evaluate the model
y_pred = log_classifier.predict(X_test)

print(f" Logistic regression model accuracy: {accuracy_score(y_test, y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
===============================================================================
#### haing trained with Logistic Model, we get an accuracy of 73%
===============================================================================
#### we now need to train the Neural network
##### - w/w compile and evaluate nn model
##### - parameters used include:
   ###### --- One (1) hidden layer with units = 16 neurons, input_dim = 8
   ###### --- use activation function "relu"
   ###### --- Loss function = "binary_crossentropy", Metric = "accuracy"
   ###### --- optimizer = "adam", number of iterations/epochs = 50 (compare with 200 in logistic model)
========================================================================================================

# %%
# first we define basin nn model
nn_model=tf.keras.models.Sequential()
# add input layer to nn model
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
# add 1 hidden layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# compile the sequential model and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# train the model by fitting the the training data into the model, 50 iterations
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)


# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 1ms/step - loss: 0.6863 - accuracy: 0.5816
# Epoch 2/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6598 - accuracy: 0.6597
# Epoch 3/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6368 - accuracy: 0.7083
# Epoch 4/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.6155 - accuracy: 0.7066
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5964 - accuracy: 0.7205
# Epoch 6/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5791 - accuracy: 0.7344
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5636 - accuracy: 0.7396
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5492 - accuracy: 0.7483
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7587
# Epoch 10/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5247 - accuracy: 0.7622
# Epoch 11/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5145 - accuracy: 0.7639
# Epoch 12/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5053 - accuracy: 0.7708
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4971 - accuracy: 0.7726
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4902 - accuracy: 0.7691
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4838 - accuracy: 0.7708
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4780 - accuracy: 0.7778
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4730 - accuracy: 0.7795
# Epoch 18/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4688 - accuracy: 0.7847
# Epoch 19/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4647 - accuracy: 0.7847
# Epoch 20/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4613 - accuracy: 0.7812
# Epoch 21/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4581 - accuracy: 0.7882
# Epoch 22/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4555 - accuracy: 0.7882
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4532 - accuracy: 0.7899
# Epoch 24/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4509 - accuracy: 0.7882
# Epoch 25/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4488 - accuracy: 0.7882
# Epoch 26/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.7882
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4456 - accuracy: 0.7899
# Epoch 28/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4442 - accuracy: 0.7899
# Epoch 29/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4430 - accuracy: 0.7917
# Epoch 30/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4416 - accuracy: 0.7899
# Epoch 31/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.7917
# Epoch 32/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4395 - accuracy: 0.7934
# Epoch 33/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4385 - accuracy: 0.7917
# Epoch 34/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.7882
# Epoch 35/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4370 - accuracy: 0.7882
# Epoch 36/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.7882
# Epoch 37/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4359 - accuracy: 0.7899
# Epoch 38/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.7899
# Epoch 39/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.7899
# Epoch 40/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.7917
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.7917
# Epoch 42/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4322 - accuracy: 0.7917
# Epoch 43/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.7917
# Epoch 44/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4313 - accuracy: 0.7934
# Epoch 45/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4305 - accuracy: 0.7951
# Epoch 46/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4304 - accuracy: 0.7951
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.7969
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4291 - accuracy: 0.7969
# Epoch 49/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4285 - accuracy: 0.7969
# Epoch 50/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.7969
# 6/6 - 0s - loss: 0.4976 - accuracy: 0.7188
# Loss: 0.49756503105163574, Accuracy: 0.71875
